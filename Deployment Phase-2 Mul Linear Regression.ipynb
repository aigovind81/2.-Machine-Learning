# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_Mul_linear.sav",'rb'))
result=loaded_model.predict([[12345,123,7565,23,134]])
# Out:
# C:\Users\KRISHNABALAN\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[780403.81565083]])

# %%
    #Create the deployment file phase 2 as baby step
import pickle

# %%
    #load the model only and run the data
loaded_model=pickle.load(open("finalized_model_Mul_linear.sav",'rb'))
result=loaded_model.predict([[12345,123,7565,23,134]])
# Out:
# C:\Users\KRISHNABALAN\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[780403.81565083]])
