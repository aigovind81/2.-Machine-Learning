# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_Forest.sav",'rb'))
result=loaded_model.predict([[1243,435,6545,2,1]])
# Out:
# C:\Users\KRISHNABALAN\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([139570.38])
